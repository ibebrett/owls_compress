# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from owls_compress import markov, datasets

# %%
chain = markov.MarkovChain(datasets.datasets['train_shakespeare'], 5)

# %%
datasets.datasets.keys()
# Out:
# dict_keys(['raw_shakespeare', 'train_shakespeare', 'valid_shakespeare', 'test_shakespeare'])

# %%
context = b'ever'
total = context

for i in range(100):
    n = chain.max_sample(context)
    if n is None:
        break
    context = context[1:] + n
    total = total + n

# %%
total
# Out:
# b'ever ee'

# %%
chain.table
# Out:
# defaultdict(<function owls_compress.markov.MarkovChain.__init__.<locals>.<lambda>()>,
#             {b'Or n': defaultdict(int, {b'v': 2, b'u': 1, b't': 1}),
#              b'r ne': defaultdict(int,
#                          {b'e': 8,
#                           b'k': 1,
#                           b'r': 1,
#                           b' ': 1,
#                           b's': 3,
#                           b't': 1,
#                           b'd': 6,
#                           b'-': 1}),
#              b' nev': defaultdict(int, {b'r': 93}),
#              b'neve': defaultdict(int,
#                          {b' ': 88, b',': 3, b'-': 1, b'\n': 5, b'.': 1}),
#              b'ever': defaultdict(int,
#                          {b'b': 16,
#                           b' ': 57,
#                           b't': 16,
#                           b'd': 8,
#                           b'p': 2,
#                           b'a': 5,
#                           b'm': 13,
# ...
